# %% [markdown]
# # My equation

# %%
f(x) = 2x^2 - 4
# Out:
# f (generic function with 1 method)

# %% [markdown]
# # $$f(x) = 2x^2 - 4$$

# %%
for x = -10:10    
  println("x = ",x, ", y = ", f(x));
end
# Out:
# x = -10, y = 196
# x = -9, y = 158
# x = -8, y = 124
# x = -7, y = 94
# x = -6, y = 68
# x = -5, y = 46
# x = -4, y = 28
# x = -3, y = 14
# x = -2, y = 4
# x = -1, y = -2
# x = 0, y = -4
# x = 1, y = -2
# x = 2, y = 4
# x = 3, y = 14
# x = 4, y = 28
# x = 5, y = 46
# x = 6, y = 68
# x = 7, y = 94
# x = 8, y = 124
# x = 9, y = 158
# x = 10, y = 196

# %%
using Plots
plot(f, -10, 10) # plot f over [-10,10]
plot!(zero, -10, 10)
